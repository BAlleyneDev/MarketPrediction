# %%
import tensorflow as tf

# %%
# !conda install -y quandl
# Out:
# Collecting package metadata: ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\tusha\Anaconda3\envs\TF
#
#   added / updated specs:
#     - quandl
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     asn1crypto-0.24.0          |           py37_0         154 KB
#     cffi-1.12.2                |   py37h7a1dbc1_1         224 KB
#     chardet-3.0.4              |           py37_1         184 KB
#     cryptography-2.6.1         |   py37h7a1dbc1_0         561 KB
#     idna-2.8                   |           py37_0         101 KB
#     inflection-0.3.1           |           py37_1          11 KB
#     more-itertools-6.0.0       |           py37_0          89 KB
#     pandas-0.24.2              |   py37ha925a31_0         9.6 MB
#     pycparser-2.19             |           py37_0         173 KB
#     pyopenssl-19.0.0           |           py37_0          82 KB
#     pysocks-1.6.8              |           py37_0          22 KB
#     python-dateutil-2.8.0      |           py37_0         281 KB
#     pytz-2018.9                |           py37_0         264 KB
#     quandl-3.4.5               |           py37_0          44 KB
#     requests-2.21.0            |           py37_0          85 KB
#     urllib3-1.24.1             |           py37_0         150 KB
#     win_inet_pton-1.1.0        |           py37_0           9 KB
#     ------------------------------------------------------------
#                                            Total:        12.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   asn1crypto         pkgs/main/win-64::asn1crypto-0.24.0-py37_0
#   cffi               pkgs/main/win-64::cffi-1.12.2-py37h7a1dbc1_1
#   chardet            pkgs/main/win-64::chardet-3.0.4-py37_1
#   cryptography       pkgs/main/win-64::cryptography-2.6.1-py37h7a1dbc1_0
#   idna               pkgs/main/win-64::idna-2.8-py37_0
#   inflection         pkgs/main/win-64::inflection-0.3.1-py37_1
#   more-itertools     pkgs/main/win-64::more-itertools-6.0.0-py37_0
#   pandas             pkgs/main/win-64::pandas-0.24.2-py37ha925a31_0
#   pycparser          pkgs/main/win-64::pycparser-2.19-py37_0
#   pyopenssl          pkgs/main/win-64::pyopenssl-19.0.0-py37_0
#   pysocks            pkgs/main/win-64::pysocks-1.6.8-py37_0
#   python-dateutil    pkgs/main/win-64::python-dateutil-2.8.0-py37_0
#   pytz               pkgs/main/win-64::pytz-2018.9-py37_0
#   quandl             pkgs/main/win-64::quandl-3.4.5-py37_0
#   requests           pkgs/main/win-64::requests-2.21.0-py37_0
#   urllib3            pkgs/main/win-64::urllib3-1.24.1-py37_0
#   win_inet_pton      pkgs/main/win-64::win_inet_pton-1.1.0-py37_0
#
#
#
# Downloading and Extracting Packages
#
# more-itertools-6.0.0 | 89 KB     |            |   0%
# more-itertools-6.0.0 | 89 KB     | ########## | 100%
#
# chardet-3.0.4        | 184 KB    |            |   0%
# chardet-3.0.4        | 184 KB    | ########## | 100%
#
# quandl-3.4.5         | 44 KB     |            |   0%
# quandl-3.4.5         | 44 KB     | ########## | 100%
#
# asn1crypto-0.24.0    | 154 KB    |            |   0%
# asn1crypto-0.24.0    | 154 KB    | ########## | 100%
#
# inflection-0.3.1     | 11 KB     |            |   0%
# inflection-0.3.1     | 11 KB     | #######5   |  75%
# inflection-0.3.1     | 11 KB     | ########## | 100%
#
# cffi-1.12.2          | 224 KB    |            |   0%
# cffi-1.12.2          | 224 KB    | ########## | 100%
#
# cryptography-2.6.1   | 561 KB    |            |   0%
# cryptography-2.6.1   | 561 KB    | ########4  |  84%
# cryptography-2.6.1   | 561 KB    | ########## | 100%
#
# pyopenssl-19.0.0     | 82 KB     |            |   0%
# pyopenssl-19.0.0     | 82 KB     | ########## | 100%
#
# pycparser-2.19       | 173 KB    |            |   0%
# pycparser-2.19       | 173 KB    | ########## | 100%
#
# idna-2.8             | 101 KB    |            |   0%
# idna-2.8             | 101 KB    | ########## | 100%
#
# pysocks-1.6.8        | 22 KB     |            |   0%
# pysocks-1.6.8        | 22 KB     | ########## | 100%
#
# urllib3-1.24.1       | 150 KB    |            |   0%
# urllib3-1.24.1       | 150 KB    | #########7 |  98%
# urllib3-1.24.1       | 150 KB    | ########## | 100%
#
# requests-2.21.0      | 85 KB     |            |   0%
# requests-2.21.0      | 85 KB     | ########## | 100%
#
# pandas-0.24.2        | 9.6 MB    |            |   0%
# pandas-0.24.2        | 9.6 MB    | 7          |   8%
# pandas-0.24.2        | 9.6 MB    | #6         |  16%
# pandas-0.24.2        | 9.6 MB    | ##7        |  27%
# pandas-0.24.2        | 9.6 MB    | ###8       |  38%
# pandas-0.24.2        | 9.6 MB    | ####6      |  47%
# pandas-0.24.2        | 9.6 MB    | #####6     |  56%
# pandas-0.24.2        | 9.6 MB    | ######7    |  67%
# pandas-0.24.2        | 9.6 MB    | #######6   |  76%
# pandas-0.24.2        | 9.6 MB    | ########4  |  84%
# pandas-0.24.2        | 9.6 MB    | #########  |  90%
# pandas-0.24.2        | 9.6 MB    | #########4 |  95%
# pandas-0.24.2        | 9.6 MB    | #########7 |  98%
# pandas-0.24.2        | 9.6 MB    | ########## | 100%
#
# win_inet_pton-1.1.0  | 9 KB      |            |   0%
# win_inet_pton-1.1.0  | 9 KB      | ########## | 100%
#
# pytz-2018.9          | 264 KB    |            |   0%
# pytz-2018.9          | 264 KB    | #########3 |  93%
# pytz-2018.9          | 264 KB    | ########## | 100%
#
# python-dateutil-2.8. | 281 KB    |            |   0%
# python-dateutil-2.8. | 281 KB    | #########2 |  92%
# python-dateutil-2.8. | 281 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
import quandl

# %%
quandl.ApiConfig.api_key = 'zMbt6sRnVyTnre9ih5k_'

# %%
stock_data = quandl.get_table('WIKI/PRICES', ticker = ['MSFT'], 
                        date = { 'gte': '2010-12-31', 'lte': '2018-12-31' }, 
                        paginate=True)

# %%
stock_data.head()
# Out:
#      ticker       date    open    high    low  close      volume  ex-dividend  \
# None
# 0      MSFT 2018-03-27  94.940  95.139  88.51  89.47  53704562.0          0.0
# 1      MSFT 2018-03-26  90.610  94.000  90.40  93.78  55031149.0          0.0
# 2      MSFT 2018-03-23  89.500  90.460  87.08  87.18  42159397.0          0.0
# 3      MSFT 2018-03-22  91.265  91.750  89.66  89.79  37578166.0          0.0
# 4      MSFT 2018-03-21  92.930  94.050  92.21  92.48  23753263.0          0.0
#
#       split_ratio  adj_open  adj_high  adj_low  adj_close  adj_volume
# None
# 0             1.0    94.940    95.139    88.51      89.47  53704562.0
# 1             1.0    90.610    94.000    90.40      93.78  55031149.0
# 2             1.0    89.500    90.460    87.08      87.18  42159397.0
# 3             1.0    91.265    91.750    89.66      89.79  37578166.0
# 4             1.0    92.930    94.050    92.21      92.48  23753263.0

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1820 entries, 0 to 1819
# Data columns (total 14 columns):
# ticker         1820 non-null object
# date           1820 non-null datetime64[ns]
# open           1820 non-null float64
# high           1820 non-null float64
# low            1820 non-null float64
# close          1820 non-null float64
# volume         1820 non-null float64
# ex-dividend    1820 non-null float64
# split_ratio    1820 non-null float64
# adj_open       1820 non-null float64
# adj_high       1820 non-null float64
# adj_low        1820 non-null float64
# adj_close      1820 non-null float64
# adj_volume     1820 non-null float64
# dtypes: datetime64[ns](1), float64(12), object(1)
# memory usage: 199.1+ KB
