# %%
import tensorflow as tf

# %%
# !conda install -y quandl
# Out:
# Collecting package metadata: ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\tusha\Anaconda3
#
#   added / updated specs:
#     - quandl
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     inflection-0.3.1           |           py36_1          11 KB
#     more-itertools-6.0.0       |           py36_0          90 KB
#     quandl-3.4.5               |           py36_0          44 KB
#     ------------------------------------------------------------
#                                            Total:         145 KB
#
# The following NEW packages will be INSTALLED:
#
#   inflection         pkgs/main/win-64::inflection-0.3.1-py36_1
#   more-itertools     pkgs/main/win-64::more-itertools-6.0.0-py36_0
#   quandl             pkgs/main/win-64::quandl-3.4.5-py36_0
#
#
#
# Downloading and Extracting Packages
#
# quandl-3.4.5         | 44 KB     |            |   0%
# quandl-3.4.5         | 44 KB     | ########## | 100%
#
# inflection-0.3.1     | 11 KB     |            |   0%
# inflection-0.3.1     | 11 KB     | ########## | 100%
#
# more-itertools-6.0.0 | 90 KB     |            |   0%
# more-itertools-6.0.0 | 90 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
import quandl

# %%
quandl.ApiConfig.api_key = 'zMbt6sRnVyTnre9ih5k_'

# %%
stock_data = quandl.get_table('WIKI/PRICES', ticker = ['MSFT'], 
                        date = { 'gte': '2010-12-31', 'lte': '2018-12-31' }, 
                        paginate=True)

# %%
stock_data.head()
# Out:
#      ticker       date    open    high    low  close      volume  ex-dividend  \
# None
# 0      MSFT 2018-03-27  94.940  95.139  88.51  89.47  53704562.0          0.0
# 1      MSFT 2018-03-26  90.610  94.000  90.40  93.78  55031149.0          0.0
# 2      MSFT 2018-03-23  89.500  90.460  87.08  87.18  42159397.0          0.0
# 3      MSFT 2018-03-22  91.265  91.750  89.66  89.79  37578166.0          0.0
# 4      MSFT 2018-03-21  92.930  94.050  92.21  92.48  23753263.0          0.0
#
#       split_ratio  adj_open  adj_high  adj_low  adj_close  adj_volume
# None
# 0             1.0    94.940    95.139    88.51      89.47  53704562.0
# 1             1.0    90.610    94.000    90.40      93.78  55031149.0
# 2             1.0    89.500    90.460    87.08      87.18  42159397.0
# 3             1.0    91.265    91.750    89.66      89.79  37578166.0
# 4             1.0    92.930    94.050    92.21      92.48  23753263.0
