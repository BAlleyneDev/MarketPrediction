# %%
import tensorflow as tf

# !conda install -y quandl
# Out:
# Collecting package metadata: ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
import quandl
quandl.ApiConfig.api_key = 'zMbt6sRnVyTnre9ih5k_'

stock_data = quandl.get_table('WIKI/PRICES', ticker = ['MSFT'],
 
                        date = { 'gte': '2010-12-31', 'lte': '2018-12-31' }, 
                        paginate=True)

# %%
stock_data = stock_data.iloc[::-1]

# %%
stock_data.head()
# Out:
#      ticker       date   open   high    low    close      volume  ex-dividend  \
# None
# 1819   MSFT 2010-12-31  27.80  27.92  27.63  27.9100  24752000.0          0.0
# 1818   MSFT 2011-01-03  28.05  28.18  27.92  27.9800  53443800.0          0.0
# 1817   MSFT 2011-01-04  27.94  28.17  27.85  28.0875  54405600.0          0.0
# 1816   MSFT 2011-01-05  27.90  28.01  27.77  28.0000  58998700.0          0.0
# 1815   MSFT 2011-01-06  28.04  28.85  27.86  28.8200  88026300.0          0.0
#
#       split_ratio   adj_open   adj_high    adj_low  adj_close  adj_volume
# None
# 1819          1.0  23.062244  23.161793  22.921216  23.153497  24752000.0
# 1818          1.0  23.269638  23.377483  23.161793  23.211568  53443800.0
# 1817          1.0  23.178385  23.369187  23.103723  23.300747  54405600.0
# 1816          1.0  23.145201  23.236455  23.037356  23.228159  58998700.0
# 1815          1.0  23.261342  23.933300  23.112018  23.908412  88026300.0

# %%
stock_data = stock_data.reset_index()
stock_data.head()
# Out:
#    None ticker       date   open   high    low    close      volume  \
# 0  1819   MSFT 2010-12-31  27.80  27.92  27.63  27.9100  24752000.0
# 1  1818   MSFT 2011-01-03  28.05  28.18  27.92  27.9800  53443800.0
# 2  1817   MSFT 2011-01-04  27.94  28.17  27.85  28.0875  54405600.0
# 3  1816   MSFT 2011-01-05  27.90  28.01  27.77  28.0000  58998700.0
# 4  1815   MSFT 2011-01-06  28.04  28.85  27.86  28.8200  88026300.0
#
#    ex-dividend  split_ratio   adj_open   adj_high    adj_low  adj_close  \
# 0          0.0          1.0  23.062244  23.161793  22.921216  23.153497
# 1          0.0          1.0  23.269638  23.377483  23.161793  23.211568
# 2          0.0          1.0  23.178385  23.369187  23.103723  23.300747
# 3          0.0          1.0  23.145201  23.236455  23.037356  23.228159
# 4          0.0          1.0  23.261342  23.933300  23.112018  23.908412
#
#    adj_volume
# 0  24752000.0
# 1  53443800.0
# 2  54405600.0
# 3  58998700.0
# 4  88026300.0

# %%
stock_shift = stock_data.shift(periods=1)
stock_shift.head()
# Out:
#      None ticker       date   open   high    low    close      volume  \
# 0     NaN    NaN        NaT    NaN    NaN    NaN      NaN         NaN
# 1  1819.0   MSFT 2010-12-31  27.80  27.92  27.63  27.9100  24752000.0
# 2  1818.0   MSFT 2011-01-03  28.05  28.18  27.92  27.9800  53443800.0
# 3  1817.0   MSFT 2011-01-04  27.94  28.17  27.85  28.0875  54405600.0
# 4  1816.0   MSFT 2011-01-05  27.90  28.01  27.77  28.0000  58998700.0
#
#    ex-dividend  split_ratio   adj_open   adj_high    adj_low  adj_close  \
# 0          NaN          NaN        NaN        NaN        NaN        NaN
# 1          0.0          1.0  23.062244  23.161793  22.921216  23.153497
# 2          0.0          1.0  23.269638  23.377483  23.161793  23.211568
# 3          0.0          1.0  23.178385  23.369187  23.103723  23.300747
# 4          0.0          1.0  23.145201  23.236455  23.037356  23.228159
#
#    adj_volume
# 0         NaN
# 1  24752000.0
# 2  53443800.0
# 3  54405600.0
# 4  58998700.0

# %%
stock_data.head()
# Out:
#      ticker       date   open   high    low    close      volume  ex-dividend  \
# None
# 1818   MSFT 2011-01-03  28.05  28.18  27.92  27.9800  53443800.0          0.0
# 1817   MSFT 2011-01-04  27.94  28.17  27.85  28.0875  54405600.0          0.0
# 1816   MSFT 2011-01-05  27.90  28.01  27.77  28.0000  58998700.0          0.0
# 1815   MSFT 2011-01-06  28.04  28.85  27.86  28.8200  88026300.0          0.0
# 1814   MSFT 2011-01-07  28.64  28.74  28.25  28.6000  73762000.0          0.0
#
#       split_ratio   adj_open   adj_high    adj_low  adj_close  adj_volume  \
# None
# 1818          1.0  23.269638  23.377483  23.161793  23.211568  53443800.0
# 1817          1.0  23.178385  23.369187  23.103723  23.300747  54405600.0
# 1816          1.0  23.145201  23.236455  23.037356  23.228159  58998700.0
# 1815          1.0  23.261342  23.933300  23.112018  23.908412  88026300.0
# 1814          1.0  23.759089  23.842046  23.435553  23.725905  73762000.0
#
#            ret
# None
# 1818  0.002505
# 1817  0.003835
# 1816 -0.003120
# 1815  0.028865
# 1814 -0.007663

# %%
stock_shift.head()
# Out:
#      ticker       date   open   high    low    close      volume  ex-dividend  \
# None
# 1819    NaN        NaT    NaN    NaN    NaN      NaN         NaN          NaN
# 1818   MSFT 2010-12-31  27.80  27.92  27.63  27.9100  24752000.0          0.0
# 1817   MSFT 2011-01-03  28.05  28.18  27.92  27.9800  53443800.0          0.0
# 1816   MSFT 2011-01-04  27.94  28.17  27.85  28.0875  54405600.0          0.0
# 1815   MSFT 2011-01-05  27.90  28.01  27.77  28.0000  58998700.0          0.0
#
#       split_ratio   adj_open   adj_high    adj_low  adj_close  adj_volume  \
# None
# 1819          NaN        NaN        NaN        NaN        NaN         NaN
# 1818          1.0  23.062244  23.161793  22.921216  23.153497  24752000.0
# 1817          1.0  23.269638  23.377483  23.161793  23.211568  53443800.0
# 1816          1.0  23.178385  23.369187  23.103723  23.300747  54405600.0
# 1815          1.0  23.145201  23.236455  23.037356  23.228159  58998700.0
#
#            ret
# None
# 1819       NaN
# 1818  0.002505
# 1817  0.003835
# 1816 -0.003120
# 1815  0.028865

# %%
import numpy as np 
ret =[]

stock_data['ret'] = np.log(stock_data['close']) - np.log(stock_shift['close'])

#stock_shift.head()

stock_data= stock_data.drop([0])

# %%
# Out:
# (1819, 15)

# %%
stock_shift = stock_data

# %%
train_size = int(len(stock_shift)*0.90)
test_size = len(stock_shift) - train_size

train ,test   = stock_shift.iloc[0:train_size] , stock_shift.iloc[train_size:len(stock_shift)]

# %%
train.head()
# Out:
#    None ticker       date   open   high    low    close      volume  \
# 1  1818   MSFT 2011-01-03  28.05  28.18  27.92  27.9800  53443800.0
# 2  1817   MSFT 2011-01-04  27.94  28.17  27.85  28.0875  54405600.0
# 3  1816   MSFT 2011-01-05  27.90  28.01  27.77  28.0000  58998700.0
# 4  1815   MSFT 2011-01-06  28.04  28.85  27.86  28.8200  88026300.0
# 5  1814   MSFT 2011-01-07  28.64  28.74  28.25  28.6000  73762000.0
#
#    ex-dividend  split_ratio   adj_open   adj_high    adj_low  adj_close  \
# 1          0.0          1.0  23.269638  23.377483  23.161793  23.211568
# 2          0.0          1.0  23.178385  23.369187  23.103723  23.300747
# 3          0.0          1.0  23.145201  23.236455  23.037356  23.228159
# 4          0.0          1.0  23.261342  23.933300  23.112018  23.908412
# 5          0.0          1.0  23.759089  23.842046  23.435553  23.725905
#
#    adj_volume       ret
# 1  53443800.0  0.002505
# 2  54405600.0  0.003835
# 3  58998700.0 -0.003120
# 4  88026300.0  0.028865
# 5  73762000.0 -0.007663

# %%
test.head()
# Out:
#       None ticker       date   open   high    low  close      volume  \
# 1638   181   MSFT 2017-07-06  68.27  68.78  68.12  68.57  20776555.0
# 1639   180   MSFT 2017-07-07  68.70  69.84  68.70  69.46  15897154.0
# 1640   179   MSFT 2017-07-10  69.46  70.25  69.20  69.98  14903400.0
# 1641   178   MSFT 2017-07-11  70.00  70.68  69.75  69.99  16880205.0
# 1642   177   MSFT 2017-07-12  70.69  71.28  70.55  71.15  17382861.0
#
#       ex-dividend  split_ratio   adj_open   adj_high    adj_low  adj_close  \
# 1638          0.0          1.0  67.566308  68.071051  67.417854  67.863216
# 1639          0.0          1.0  67.991876  69.120125  67.991876  68.744042
# 1640          0.0          1.0  68.744042  69.525899  68.486722  69.258682
# 1641          0.0          1.0  69.278476  69.951467  69.031053  69.268579
# 1642          0.0          1.0  69.961364  70.545283  69.822807  70.416623
#
#       adj_volume       ret
# 1638  20776555.0 -0.007410
# 1639  15897154.0  0.012896
# 1640  14903400.0  0.007458
# 1641  16880205.0  0.000143
# 1642  17382861.0  0.016438

# %%
X_train = []
Y_train = []

X_test = []
Y_test = []

for i in range(60,1637):
    X_train.append(train['ret'][i-60:i])
    Y_train.append(train['ret'][i])

for i in range(1638+60,(len(train)+len(test))):
    X_test.append(test['ret'][i-60:i])
    Y_test.append(test['ret'][i])

X_train,Y_train = np.array(X_train),np.array(Y_train)

X_test,Y_test = np.array(X_test),np.array(Y_test)

# %%
train.head(60)
# Out:
#     None ticker       date    open     high      low    close       volume  \
# 1   1818   MSFT 2011-01-03  28.050  28.1800  27.9200  27.9800   53443800.0
# 2   1817   MSFT 2011-01-04  27.940  28.1700  27.8500  28.0875   54405600.0
# 3   1816   MSFT 2011-01-05  27.900  28.0100  27.7700  28.0000   58998700.0
# 4   1815   MSFT 2011-01-06  28.040  28.8500  27.8600  28.8200   88026300.0
# 5   1814   MSFT 2011-01-07  28.640  28.7400  28.2500  28.6000   73762000.0
# 6   1813   MSFT 2011-01-10  28.260  28.4000  28.0400  28.2200   57573600.0
# 7   1812   MSFT 2011-01-11  28.200  28.2500  28.0500  28.1100   50298900.0
# 8   1811   MSFT 2011-01-12  28.120  28.5900  28.0700  28.5500   52631100.0
# 9   1810   MSFT 2011-01-13  28.330  28.3900  28.0100  28.1900   67077600.0
# 10  1809   MSFT 2011-01-14  28.080  28.3800  27.9100  28.3000   62688400.0
# 11  1808   MSFT 2011-01-18  28.160  28.7400  28.1400  28.6600   53322700.0
# 12  1807   MSFT 2011-01-19  28.460  28.6800  28.2700  28.4700   50005900.0
# 13  1806   MSFT 2011-01-20  28.500  28.5500  28.1300  28.3525   58613600.0
# 36         0.00          1.0  22.139296  22.414681  22.055846  22.189366
# 37         0.00          1.0  22.231091  22.581581  22.114261  22.339576
# 38         0.00          1.0  22.456406  22.489786  22.114261  22.155986
# 39         0.00          1.0  22.272816  22.414681  22.122606  22.181021
# 40         0.00          1.0  22.197711  22.347921  21.822186  21.830531
# 41         0.00          1.0  21.788806  22.005776  21.730391  21.761685
# 42         0.00          1.0  21.913981  22.030811  21.847221  21.863911
# 43         0.00          1.0  21.880601  21.897291  21.530111  21.657372
# 44         0.00          1.0  21.805496  21.922326  21.321486  21.463351
# 45         0.00          1.0  21.505076  21.713701  21.404936  21.621906
# 46         0.00          1.0  21.538456  21.680321  21.413281  21.605216
# 47         0.00          1.0  21.379901  21.455006  21.154586  21.204656
# 48         0.00          1.0  21.204656  21.571836  21.162931  21.429971
# 49         0.00          1.0  21.271416  21.496731  21.154586  21.438316
# 50         0.00          1.0  20.929271  21.254726  20.862510  21.187966
# 51         0.00          1.0  21.046101  21.096171  20.595470  20.687265
# 52         0.00          1.0  20.912580  21.046101  20.653885  20.678920
# 53         0.00          1.0  20.912580  21.012721  20.693858  20.695610
# 54         0.00          1.0  21.012721  21.346521  20.987686  21.137896
# 55         0.00          1.0  21.112861  21.246381  21.054446  21.108688
# 56         0.00          1.0  21.054446  21.371556  21.012721  21.313141
# 57         0.00          1.0  21.363211  21.588526  21.279761  21.538456
# 58         0.00          1.0  21.638596  21.655286  21.354866  21.379901
# 59         0.00          1.0  21.413281  21.463351  21.179621  21.204656
# 60         0.00          1.0  21.146241  21.296451  21.112861  21.271416
#
#      adj_volume       ret
# 1    53443800.0  0.002505
# 2    54405600.0  0.003835
# 3    58998700.0 -0.003120
# 4    88026300.0  0.028865
# 5    73762000.0 -0.007663
# 6    57573600.0 -0.013376
# 7    50298900.0 -0.003906
# 8    52631100.0  0.015532
# 9    67077600.0 -0.012690
# 10   62688400.0  0.003894
# 11   53322700.0  0.012641
# 12   50005900.0 -0.006652
# 13   58613600.0 -0.004136
# 14   58080300.0 -0.011797
# 15   52047800.0  0.012766
# 16   42436600.0  0.002463
# 17   74628800.0  0.011533
# 18  146938600.0  0.003122
# 19  141249400.0 -0.039531
# 20   65029000.0 -0.000937
# 21   62810700.0  0.009602
# 22   45824000.0 -0.001877
# 23   60340100.0 -0.010434
# 24   40412200.0  0.004331
# 25   68980900.0  0.015277
# 26   34904200.0  0.003010
# 27   52905100.0 -0.011111
# 28   76672400.0 -0.016947
# 29   83939700.0 -0.009132
# 30   56766200.0 -0.000734
# 31   44116500.0 -0.009965
# 32   70817900.0  0.002223
# 33   57207300.0  0.007007
# 34   68667800.0 -0.005528
# 35   60889000.0 -0.017521
# 36   60234100.0  0.000000
# 37   64494200.0  0.006747
# 38   53006300.0 -0.008252
# 39   51379900.0  0.001129
# 40   60055000.0 -0.015928
# 41   48658200.0 -0.003159
# 42   68271500.0  0.004687
# 43   70437200.0 -0.009491
# 44   64980400.0 -0.008999
# 45   50549800.0  0.007360
# 46   39789100.0 -0.000772
# 47   66549500.0 -0.018714
# 48   49905800.0  0.010570
# 49   54473400.0  0.000389
# 50   76067300.0 -0.011746
# 51  100725400.0 -0.023915
# 52   62497000.0 -0.000403
# 53   85486700.0  0.000807
# 54   46878100.0  0.021146
# 55   30895600.0 -0.001383
# 56   43969000.0  0.009639
# 57   38696700.0  0.010516
# 58   57029800.0 -0.007389
# 59   48973200.0 -0.008230
# 60   40763500.0  0.003143

# %%
print(X_train)
# Out:
# [[ 0.00250492  0.00383467 -0.00312013 ... -0.00738872 -0.0082305
#    0.00314342]
#  [ 0.00383467 -0.00312013  0.02886508 ... -0.0082305   0.00314342
#    0.00469668]
#  [-0.00312013  0.02886508 -0.00766287 ...  0.00314342  0.00469668
#   -0.0086275 ]
#  ...
#  [-0.00258969  0.00258969 -0.00076098 ... -0.01889279  0.00848865
#   -0.01894626]
#  [ 0.00258969 -0.00076098 -0.00228641 ...  0.00848865 -0.01894626
#    0.00640375]
#  [-0.00076098 -0.00228641 -0.0007633  ... -0.01894626  0.00640375
#   -0.01108691]]

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
from tensorflow.python import keras 
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers.core import Dense, Dropout
from tensorflow.python.keras.callbacks import History
from tensorflow.python.keras.layers.recurrent import LSTM
from tensorflow.python.keras.models import model_from_json
from tensorflow.python.keras.regularizers import l2

from tensorflow.python.keras import backend as K

regressor = Sequential()

regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (x_train.shape[1], 1)))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

regressor.add(Dense(units = 1))

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

regressor.fit(X_train, Y_train, epochs = 10, batch_size = 32)
# Out:
# Epoch 1/10
# 1577/1577 [==============================] - 14s 9ms/sample - loss: 2.2427e-04
# Epoch 2/10
# 1577/1577 [==============================] - 9s 6ms/sample - loss: 2.1499e-04
# Epoch 3/10
# 1577/1577 [==============================] - 8s 5ms/sample - loss: 2.1666e-04
# Epoch 4/10
# 1577/1577 [==============================] - 8s 5ms/sample - loss: 2.1632e-04
# Epoch 5/10
# 1577/1577 [==============================] - 8s 5ms/sample - loss: 2.1446e-04
# Epoch 6/10
# 1577/1577 [==============================] - 9s 6ms/sample - loss: 2.1241e-04
# Epoch 7/10
# 1577/1577 [==============================] - 8s 5ms/sample - loss: 2.1485e-04
# Epoch 8/10
# 1577/1577 [==============================] - 9s 6ms/sample - loss: 2.1172e-04
# Epoch 9/10
# 1577/1577 [==============================] - 9s 6ms/sample - loss: 2.1710e-04
# Epoch 10/10
# 1577/1577 [==============================] - 9s 6ms/sample - loss: 2.1244e-04

# %%
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-6225e5a8c6c0> in <module>()
#       1 X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
# ----> 2 predicted_stock_price = regressor.predict(X_test)
#       3 predicted_stock_price = sc.inverse_transform(predicted_stock_price)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, max_queue_size, workers, use_multiprocessing)
#    1094       # batch size.
#    1095       x, _, _ = self._standardize_user_data(
# -> 1096           x, check_steps=True, steps_name='steps', steps=steps)
#    1097
#    1098     if (self.run_eagerly or (isinstance(x, iterator_ops.EagerIterator) and
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split, shuffle)
#    2380         feed_input_shapes,
#    2381         check_batch_axis=False,  # Don't enforce the batch size.
# -> 2382         exception_prefix='input')
#    2383
#    2384     if y is not None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     360                 'Error when checking ' + exception_prefix + ': expected ' +
#     361                 names[i] + ' to have shape ' + str(shape) +
# --> 362                 ' but got array with shape ' + str(data_shape))
#     363   return data
#     364
#
# ValueError: Error when checking input: expected lstm_8_input to have shape (60, 1) but got array with shape (0, 1)

# %%
X_test.shape
# Out:
# (121, 0, 1)

# %%
import matplotlib.pyplot as plt

plt.plot(Y_test, color = 'black', label = 'TATA Stock Price')
plt.plot(predicted_stock_price, color = 'green', label = 'Predicted TATA Stock Price')
plt.title('TATA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('TATA Stock Price')
plt.legend()
plt.show()
